# %%
import pandas as pd
import numpy as num

# %%
data={'name':['jayant','suman','neha','suresh'],'id':[101,102,103,104]}         # data in the form of dictonary
df=pd.DataFrame(data)                              # this code will convert dictonary data in the form of data frames..
df
# Out:
#      name   id
# 0  jayant  101
# 1   suman  102
# 2    neha  103
# 3  suresh  104

# %%
df.head(2)  # this code will show first two datas from the data frame...
# Out:
#      name   id
# 0  jayant  101
# 1   suman  102

# %%
df.tail(2)   # last two data from the data frame
# Out:
#      name   id
# 2    neha  103
# 3  suresh  104

# %%
df.describe()     # it will describe all the deatils of the data frame...
# Out:
#                id
# count    4.000000
# mean   102.500000
# std      1.290994
# min    101.000000
# 25%    101.750000
# 50%    102.500000
# 75%    103.250000
# max    104.000000

# %%
df.to_csv("student.csv")    # this code will add data in csv file(i,e MS. excel)

# %%
df.to_csv("stu.csv",index=False)    # this code will add data in csv file but without index...

# %%
pd.read_csv("stu.csv")        # this code will read data from the csv file..
# Out:
#      name   id
# 0  jayant  101
# 1   suman  102
# 2    neha  103
# 3  suresh  104

# %%
newdf=pd.DataFrame(num.random.rand(334,5),index=num.arange(334))    # first paramter will generate random data upto 333 with index upto 4 and second paramter will generate index upto 333..
newdf
# Out:
#             0         1         2         3         4
# 0    0.976644  0.360595  0.742867  0.481485  0.560546
# 1    0.440394  0.916151  0.627092  0.521171  0.220444
# 2    0.115041  0.937887  0.456665  0.488426  0.463862
# 3    0.577654  0.264750  0.521670  0.001918  0.544030
# 4    0.700019  0.609633  0.646638  0.105207  0.948583
# 5    0.189043  0.425912  0.418545  0.336156  0.485914
# 6    0.310747  0.963134  0.841382  0.380354  0.022689
# 7    0.846083  0.377710  0.161527  0.705521  0.849131
# 8    0.281115  0.654998  0.119407  0.626301  0.432202
# 9    0.728460  0.704343  0.363251  0.227140  0.569405
# 10   0.136194  0.568774  0.908322  0.035534  0.742309
# 11   0.312977  0.246110  0.776079  0.619255  0.558858
# 12   0.039959  0.714162  0.074340  0.278895  0.341746
# 13   0.900055  0.305230  0.121404  0.391356  0.939906
# 14   0.084009  0.707675  0.638760  0.234168  0.419393
# 15   0.574288  0.818228  0.282381  0.610610  0.912578
# ...

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf[0][0]="jks"

# %%
newdf.head(2)
# Out:
#            0         1         2         3         4
# 0        jks  0.454334  0.483058  0.400540  0.225990
# 1  0.0119733  0.344584  0.493904  0.656975  0.502181

# %%
newdf.dtypes
# Out:
# 0     object
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf.dtypes
# Out:
# 0      int64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf.head(2)
# Out:
#     0         1         2         3         4
# 0   1  0.454334  0.483058  0.400540  0.225990
# 1  12  0.344584  0.493904  0.656975  0.502181

# %%
newdf
# Out:
#       0         1         2         3         4
# 0     1  0.454334  0.483058  0.400540  0.225990
# 1    12  0.344584  0.493904  0.656975  0.502181
# 2    12  0.282063  0.255385  0.069902  0.744987
# 3    12  0.529928  0.300246  0.578448  0.876155
# 4    12  0.332843  0.240536  0.569205  0.915531
# %%
newdf.iloc[[0,1],[1,2]]
# Out:
#           B         C
# 0  0.360595  0.742867
# 1  0.916151  0.627092

# %%
newdf.loc[[0,1],:]
# Out:
#             A         B         C         D         E
# 0  788.000000  0.360595  0.742867  0.481485  0.560546
# 1    0.440394  0.916151  0.627092  0.521171  0.220444

# %%
newdf.iloc[0,1]
# Out:
# 0.3605947139360124

# %%
newdf.iloc[[0]]
# Out:
#        A         B         C         D         E
# 0  788.0  0.360595  0.742867  0.481485  0.560546

# %%
newdf.drop([0])
# Out:
#             A         B         C         D         E
# 1    0.440394  0.916151  0.627092  0.521171  0.220444
# 2    0.115041  0.937887  0.456665  0.488426  0.463862
# 3    0.577654  0.264750  0.521670  0.001918  0.544030
# 4    0.700019  0.609633  0.646638  0.105207  0.948583
# 5    0.189043  0.425912  0.418545  0.336156  0.485914
# 6    0.310747  0.963134  0.841382  0.380354  0.022689
# 7    0.846083  0.377710  0.161527  0.705521  0.849131
# 8    0.281115  0.654998  0.119407  0.626301  0.432202
# 9    0.728460  0.704343  0.363251  0.227140  0.569405
# 10   0.136194  0.568774  0.908322  0.035534  0.742309
# 11   0.312977  0.246110  0.776079  0.619255  0.558858
# 12   0.039959  0.714162  0.074340  0.278895  0.341746
# 13   0.900055  0.305230  0.121404  0.391356  0.939906
# 14   0.084009  0.707675  0.638760  0.234168  0.419393
# 15   0.574288  0.818228  0.282381  0.610610  0.912578
# 16   0.320164  0.345626  0.827542  0.558258  0.692873
# ...

# %%
newdf.drop(['A'],axis=1)
# Out:
#             B         C         D         E
# 0    0.360595  0.742867  0.481485  0.560546
# 1    0.916151  0.627092  0.521171  0.220444
# 2    0.937887  0.456665  0.488426  0.463862
# 3    0.264750  0.521670  0.001918  0.544030
# 4    0.609633  0.646638  0.105207  0.948583
# 5    0.425912  0.418545  0.336156  0.485914
# 6    0.963134  0.841382  0.380354  0.022689
# 7    0.377710  0.161527  0.705521  0.849131
# 8    0.654998  0.119407  0.626301  0.432202
# 9    0.704343  0.363251  0.227140  0.569405
# 10   0.568774  0.908322  0.035534  0.742309
# 11   0.246110  0.776079  0.619255  0.558858
# 12   0.714162  0.074340  0.278895  0.341746
# 13   0.305230  0.121404  0.391356  0.939906
# 14   0.707675  0.638760  0.234168  0.419393
# 15   0.818228  0.282381  0.610610  0.912578
# 16   0.345626  0.827542  0.558258  0.692873
# 17   0.317327  0.798767  0.903845  0.808156
# 18   0.013956  0.467507  0.585464  0.678965
# 19   0.138666  0.933917  0.884860  0.309989
# ...

# %%
info={'one':pd.Series([1,2,3,4,5]),'two':pd.Series([2,56,6,18,9])}
data=pd.DataFrame(info)
data
data['three']=pd.Series([90,23,12,91,87])
data
# Out:
#    one  two  three
# 0    1    2     90
# 1    2   56     23
# 2    3    6     12
# 3    4   18     91
# 4    5    9     87

# %%
data['four']=data['one']+data['three']
data
# Out:
#    one  two  three  four
# 0    1    2     90    91
# 1    2   56     23    25
# 2    3    6     12    15
# 3    4   18     91    95
# 4    5    9     87    92

# %%
data.loc[[0]]
# Out:
#    one  two  three  four
# 0    1    2     90    91

# %%
data.iloc[[2]]
# Out:
#    one  two  three  four
# 2    3    6     12    15

# %%
data[2:4]
# Out:
#    one  two  three  four
# 2    3    6     12    15
# 3    4   18     91    95

# %%
info1=pd.DataFrame({"x":[12,34,12,45,67],"y":[14,56,12,44,11]})
info2=pd.DataFrame({"x":[90,22,12,55,22],"y":[0,56,23,11,23],"z":[23,45,11,5,77]})
info1.append(info2,ignore_index=True,sort=False)
# Out:
#     x   y     z
# 0  12  14   NaN
# 1  34  56   NaN
# 2  12  12   NaN
# 3  45  44   NaN
# 4  67  11   NaN
# 5  90   0  23.0
# 6  22  56  45.0
# 7  12  23  11.0
# 8  55  11   5.0
# 9  22  23  77.0

# %%
info1
# Out:
#     x   y
# 0  12  14
# 1  34  56
# 2  12  12
# 3  45  44
# 4  67  11

# %%
num.sum(info1)
# Out:
# x    170
# y    137
# dtype: int64

# %%
x=lambda x:print(x)
x(4)
# Out:
# 4

# %%
info1.agg(['sum'])
# Out:
#        x    y
# sum  170  137

# %%
info1.agg(['sum','min','max'])
# Out:
#        x    y
# sum  170  137
# min   12   11
# max   67   56

# %%
info3=pd.DataFrame()

# %%
info3['ID']=[101,102,103,104]
info3.assign(NAME=["jayant","smith","parker","john"])
# Out:
#     ID    NAME
# 0  101  jayant
# 1  102   smith
# 2  103  parker
# 3  104    john

# %%
info3.count()
# Out:
# ID    4
# dtype: int64

# %%
data1=pd.DataFrame({'name':["jayant","john","jay","john","smith","john"]})
data1
# Out:
#      name
# 0  jayant
# 1    john
# 2     jay
# 3    john
# 4   smith
# 5    john

# %%
data1=data1.drop_duplicates()
data1
# Out:
#      name
# 0  jayant
# 1    john
# 2     jay
# 4   smith

# %%
data2=pd.DataFrame({'length':[2,3,1,5,6,1],'width':[2,6,2,2,5,7]})
hist=data2.hist()
hist
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000201A8897D68>,
# ...
#       dtype=object)

# %%
info=pd.DataFrame(num.random.randn(4,2))
info
# Out:
#           0         1
# 0  0.030424  1.102289
# 1  0.209436  0.907444
# 2  2.648018  1.075721
# 3 -0.037891  1.018455

# %%
for rowindex,row in info.iterrows():
    print(rowindex,row)
# Out:
# 0 0    0.030424
# 1    1.102289
# Name: 0, dtype: float64
# 1 0    0.209436
# 1    0.907444
# Name: 1, dtype: float64
# 2 0    2.648018
# 1    1.075721
# Name: 2, dtype: float64
# 3 0   -0.037891
# 1    1.018455
# Name: 3, dtype: float64
